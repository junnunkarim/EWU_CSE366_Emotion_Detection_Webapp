# %% [markdown]
# # Install Libraries

# %%
# %%capture
# installs unsloth, xformers (flash attention)
# !pip install -q "unsloth[colab-new] @ git+https://github.com/unslothai/unsloth.git"
# !pip install -q --no-deps xformers trl peft accelerate bitsandbytes

# !pip install -q -U datasets
# !pip install -q -U evaluate
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.4/102.4 kB 1.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 542.0/542.0 kB 11.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 11.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 20.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 13.1 MB/s eta 0:00:00
#   Building wheel for unsloth (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 222.7/222.7 MB 5.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 245.2/245.2 kB 20.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 251.6/251.6 kB 27.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.6/302.6 kB 29.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.8/119.8 MB 8.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 3.7 MB/s eta 0:00:00

# %% [markdown]
# # Model Preparation

# %%
import torch
from unsloth import FastLanguageModel
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.

# %%
# pretrained model to load from huggingface
model_name = "google/gemma-2b"

# model_name = "unsloth/mistral-7b-instruct-v0.3-bnb-4bit"
# model_name = "unsloth/llama-3-8b-bnb-4bit"
# model_name = "unsloth/Phi-3-mini-4k-instruct"
# model_name = "unsloth/Phi-3-medium-4k-instruct"

# maximum number of tokens the model can handle at once
# 2048 means the model can process sequences of up to 2048 words or sub-words
max_seq_length = 2048
# `None` for auto detection. Float16 for Tesla T4 and V100, Bfloat16 for Ampere+
dtype = None
# use 4bit quantization to reduce memory usage
load_in_4bit = True
# personal huggingface access token
access_auth = "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"

model, tokenizer = FastLanguageModel.from_pretrained(
    model_name=model_name,
    max_seq_length=max_seq_length,
    dtype=dtype,
    load_in_4bit=load_in_4bit,
    token=access_auth,
)

# eos_token is used to mark the end-of-sequence or a piece of text in data
EOS_TOKEN = tokenizer.eos_token
tokenizer.pad_token = tokenizer.eos_token
# Out:
# config.json:   0%|          | 0.00/627 [00:00<?, ?B/s]
# ==((====))==  Unsloth: Fast Gemma patching release 2024.5
#    \\   /|    GPU: Tesla T4. Max memory: 14.748 GB. Platform = Linux.
# O^O/ \_/ \    Pytorch: 2.3.0+cu121. CUDA = 7.5. CUDA Toolkit = 12.1.
# \        /    Bfloat16 = FALSE. Xformers = 0.0.26.post1. FA = False.
#  "-____-"     Free Apache license: http://github.com/unslothai/unsloth
# model.safetensors.index.json:   0%|          | 0.00/13.5k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.95G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/67.1M [00:00<?, ?B/s]
# `config.hidden_act` is ignored, you should use `config.hidden_activation` instead.
# Gemma's activation function will be set to `gelu_pytorch_tanh`. Please, use
# `config.hidden_activation` if you want to override this behaviour.
# See https://github.com/huggingface/transformers/pull/29402 for more details.
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/137 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/33.6k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/4.24M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/636 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.5M [00:00<?, ?B/s]

# %%
# PEFT allows to fine-tune a large model on a specific task using only a small
# subset of its parameters, reducing computational cost and memory usage

# This defines a list of module names within the LLM that will be used for PEFT.
# q_proj: Query projection
# k_proj: Key projection
# v_proj: Value projection
# o_proj: Output projection
# gate_proj: Gate projection
# up_proj: Upsampling projection
# down_proj: Downsampling projection
target_modules = [
    "q_proj",
    "k_proj",
    "v_proj",
    "o_proj",
    "gate_proj",
    "up_proj",
    "down_proj",
]

model = FastLanguageModel.get_peft_model(
    model,
    # controls the rank of the low-rank factorization used in PEFT.
    # higher values of r allow for more fine-tuning capacity but might require more memory
    # choose any number > 0
    # suggested 8, 16, 32, 64, 128
    r=32,
    target_modules=target_modules,
    # controls the scaling factor applied to the low-rank factors during training.
    lora_alpha=16,
    # dropout rate helps prevent overfitting by randomly dropping out a certain
    # percentage of activations during training
    lora_dropout=0,  # supports any, but = 0 is optimized
    bias="none",  # supports any, but = "none" is optimized
    # gradient checkpointing only stores the activations needed to compute
    # gradients for a subset of the model layers at a time, instead of storing
    # all activations throughout the entire model.
    use_gradient_checkpointing="True",
    random_state=42,
    use_rslora=False,  # we support rank stabilized LoRA
    loftq_config=None,  # and LoftQ
)

# `pad_token_id` placeholder for sequences that are shorter than a fixed length required by the model
model.generation_config.pad_token_ids = tokenizer.pad_token_id
# Out:
# Unsloth 2024.5 patched 18 layers with 18 QKV layers, 18 O layers and 18 MLP layers.

# %% [markdown]
# # Data Preparation

# %%
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

from datasets import load_dataset, DatasetDict

# %%
# mount google drive
from google.colab import drive

drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# load dataset in pandas for some analysis
df = pd.read_csv(
    "/content/drive/MyDrive/datasets/bangla_sentiment_and_emotion_analysis.csv"
)

# print first and last 5 rows
df
# Out:
#        Rating                                             Review  \
# 0         5.0  অসাধারণ ফোন।অনেক পছন্দ হয়েছে।একদম অথেনটিক শাও...
# 1         5.0  Phone is good according to my uses, Upgraded f...
# 2         5.0                  অল্প দামে দারুন একটা স্মার্টফোন 💙
# 3         5.0            Super Fast Delivery ,11200 TK te pailam
# 4         5.0                    Delay Delivery... Good Product.
# ...       ...                                                ...
# 78125     5.0                                         A good one
# 78126     4.7  Overall the product was good. Thanks, Pickaboo...
# 78127     5.0  This is a very good powerbank in this price po...
# 78128     4.0  good for long lasting but after 2 year it's fa...
# 78129     5.0  Product Is Original. I Tested & Confirmed Capa...
#
#                                             Product Name Product Category  \
# 0                                    Redmi 12C (4/128GB)     Smart Phones
# 1                                    Redmi 12C (4/128GB)     Smart Phones
# 2                                    Redmi 12C (4/128GB)     Smart Phones
# 3                                    Redmi 12C (4/128GB)     Smart Phones
# 4                                    Redmi 12C (4/128GB)     Smart Phones
# ...                                                  ...              ...
# 78125  Baseus Bipow Digital Display 20W 10000mAh Powe...       Power Bank
# 78126  Baseus Bipow Digital Display 20W 10000mAh Powe...       Power Bank
# 78127  Baseus Bipow Digital Display 15W 10000mAh Powe...       Power Bank
# 78128  Baseus Bipow Digital Display 15W 10000mAh Powe...       Power Bank
# 78129  Baseus Bipow Digital Display 15W 10000mAh Powe...       Power Bank
#
#       Emotion Data Source Sentiment
# 0       Happy       Daraz  Positive
# 1       Happy       Daraz  Positive
# 2        Love       Daraz  Positive
# 3       Happy       Daraz  Positive
# 4       Happy       Daraz  Positive
# ...       ...         ...       ...
# 78125   Happy    Pickaboo  Positive
# 78126   Happy    Pickaboo  Positive
# 78127    Love    Pickaboo  Positive
# 78128   Happy    Pickaboo  Positive
# 78129   Happy    Pickaboo  Positive
#
# [78130 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78130 entries, 0 to 78129
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Rating            78130 non-null  float64
#  1   Review            78130 non-null  object
#  2   Product Name      78130 non-null  object
#  3   Product Category  78130 non-null  object
#  4   Emotion           78130 non-null  object
#  5   Data Source       78130 non-null  object
#  6   Sentiment         78130 non-null  object
# dtypes: float64(1), object(6)
# memory usage: 4.2+ MB

# %%
# print unique values in `Emotion` column with counts
df["Emotion"].value_counts()
# Out:
# Emotion
# Happy      46635
# Love       20633
# Sadness     6533
# Anger       3171
# Fear        1158
# Name: count, dtype: int64

# %%
# plot unique values in `Emotion` column with counts
plt.figure(figsize=(8, 6))
sns.countplot(data=df, x="Emotion", order=df["Emotion"].value_counts().index)
plt.title("Distribution of Emotions")
plt.xlabel("Emotion")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.show()

# %%
# if the dataset is not splitted it will be loaded as a single `train` set.
# `test` and `validation` sets are needed to be splitted manually.
dataset = load_dataset(
    "csv",
    data_files="/content/drive/MyDrive/datasets/bangla_sentiment_and_emotion_analysis.csv",
)

# remove columns that are not needed.
# keep these colmuns and remove the rest.
dataset = dataset.select_columns(["Review", "Emotion"])

# create a copy of the `Emotion` column for encoding it to integer representation
# this is done for statified split
dataset["train"] = dataset["train"].add_column(
    "Emotion_INT", dataset["train"]["Emotion"]
)

# column to stratify for splits
stratify_column = "Emotion_INT"

# convert/encode the column to ClassLabel object
dataset = dataset.class_encode_column(stratify_column)

print(dataset)
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]
# Casting to class labels:   0%|          | 0/78130 [00:00<?, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['Review', 'Emotion', 'Emotion_INT'],
#         num_rows: 78130
#     })
# })

# %%
# check out the features
print(dataset["train"].features)
# Out:
# {'Review': Value(dtype='string', id=None), 'Emotion': Value(dtype='string', id=None), 'Emotion_INT': ClassLabel(names=['Anger', 'Fear', 'Happy', 'Love', 'Sadness'], id=None)}

# %% [markdown]
# ## Split Dataset

# %%
# split the main dataset into `train` and `test` sets
train_with_test_valid = dataset["train"].train_test_split(
    test_size=0.1, stratify_by_column=stratify_column, seed=42
)

# split the `test` set from the newly splitted dataset into,
# 50% test and 50% evaluation sets
test_valid = train_with_test_valid["test"].train_test_split(
    test_size=0.5, stratify_by_column=stratify_column, seed=42
)

# combine everything into a single DatasetDict
dataset = DatasetDict(
    {
        "train": train_with_test_valid["train"],
        "test": test_valid["train"],
        "eval": test_valid["test"],
    }
)

# remove the `Emotion_INT` column now that the dataset has been split
dataset = dataset.remove_columns("Emotion_INT")

print(dataset)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['Review', 'Emotion'],
#         num_rows: 70317
#     })
#     test: Dataset({
#         features: ['Review', 'Emotion'],
#         num_rows: 3906
#     })
#     eval: Dataset({
#         features: ['Review', 'Emotion'],
#         num_rows: 3907
#     })
# })

# %%
# print the first rows for checking
print("TRAIN:\n", dataset["train"][0])
print("", dataset["train"].features)
print("TEST:\n", dataset["test"][0])
print("EVAL:\n", dataset["eval"][0])
# Out:
# TRAIN:
#  {'Review': 'mal bhalo...original', 'Emotion': 'Happy'}
#  {'Review': Value(dtype='string', id=None), 'Emotion': Value(dtype='string', id=None)}
# TEST:
#  {'Review': 'nice product. I received many compliments.', 'Emotion': 'Happy'}
# EVAL:
#  {'Review': 'প্রোডাক্ট টা অনেক ভাল ছিল , কম দামে এত ভাল জিনিস ভাবতেই পারিনি। \n\nআপনারা চাইলে নিতে পারেন, অনেক ভালো প্রোডাক্ট এটা।', 'Emotion': 'Happy'}

# %% [markdown]
# ## Format for prompting

# %%
# create prompt for `train` and `eval` sets
def format_train_prompt(data):
    texts = data["Review"]
    emotions = data["Emotion"]

    prompts = []

    for text, emotion in zip(texts, emotions):
        # must add EOS_TOKEN, otherwise your generation will go on forever
        prompt = (
            f"""Analyze the emotion of the text enclosed in square brackets,
determine if it is Happy, Love, Sadness, Anger or Fear, and return the answer only as
the corresponding sentiment label 'Happy' or 'Love' or 'Sadness' or 'Anger' or 'Fear'

[{text}] = {emotion}""".strip()
            + EOS_TOKEN
        )

        prompts.append(prompt)

    return {"Prompt": prompts}


# creat prompt for `test` set
def format_test_prompt(data):
    texts = data["Review"]
    emotions = data["Emotion"]

    prompts = []

    for text, emotion in zip(texts, emotions):
        # must add EOS_TOKEN, otherwise your generation will go on forever!
        prompt = f"""Analyze the emotion of the text enclosed in square brackets,
determine if it is Happy, Love, Sadness, Anger or Fear, and return the answer only as
the corresponding sentiment label 'Happy' or 'Love' or 'Sadness' or 'Anger' or 'Fear'

[{text}] = """.strip()

        prompts.append(prompt)

    return {"Prompt": prompts}


# format the prompts for fine-tuning
# this adds a `Prompt` column in the datasets
# batch size defaults to 1000
dataset["train"] = dataset["train"].map(format_train_prompt, batched=True)
dataset["eval"] = dataset["eval"].map(format_train_prompt, batched=True)

dataset["test"] = dataset["test"].map(format_test_prompt, batched=True)

print(dataset)
# Out:
# Map:   0%|          | 0/70317 [00:00<?, ? examples/s]
# Map:   0%|          | 0/3907 [00:00<?, ? examples/s]
# Map:   0%|          | 0/3906 [00:00<?, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['Review', 'Emotion', 'Prompt'],
#         num_rows: 70317
#     })
#     test: Dataset({
#         features: ['Review', 'Emotion', 'Prompt'],
#         num_rows: 3906
#     })
#     eval: Dataset({
#         features: ['Review', 'Emotion', 'Prompt'],
#         num_rows: 3907
#     })
# })

# %%
print("PROMPT:\n", dataset["test"][5]["Prompt"])
print("\nEMOTION:\n", dataset["test"][5]["Emotion"])
# Out:
# PROMPT:
#  Analyze the emotion of the text enclosed in square brackets,
# determine if it is Happy, Love, Sadness, Anger or Fear, and return the answer only as
# the corresponding sentiment label 'Happy' or 'Love' or 'Sadness' or 'Anger' or 'Fear'
#
# [waterproof.
# good in this price.] =
#
# EMOTION:
#  Happy

# %%
# print unique values in `Emotion` column of the `train` set with counts
print("Unique values in `train` set:")
dataset["train"].to_pandas()["Emotion"].value_counts()
# Out:
# Unique values in `train` set:
# Emotion
# Happy      41971
# Love       18570
# Sadness     5880
# Anger       2854
# Fear        1042
# Name: count, dtype: int64

# %%
# print unique values in `Emotion` column of the `validation` set with counts
print("Unique values in `validation` set:")
dataset["eval"].to_pandas()["Emotion"].value_counts()
# Out:
# Unique values in `validation` set:
# Emotion
# Happy      2332
# Love       1032
# Sadness     327
# Anger       158
# Fear         58
# Name: count, dtype: int64

# %%
# print unique values in `Emotion` column of the `test` set with counts
print("Unique values in `test` set:")
dataset["test"].to_pandas()["Emotion"].value_counts()
# Out:
# Unique values in `test` set:
# Emotion
# Happy      2332
# Love       1031
# Sadness     326
# Anger       159
# Fear         58
# Name: count, dtype: int64

# %% [markdown]
# # Fine Tuning

# %%
from trl import SFTTrainer
from transformers import TrainingArguments
from unsloth import is_bfloat16_supported

# %%
training_args = TrainingArguments(
    # specifies the batch size
    # it means each device will process 4 examples per
    # forward/backward pass per device
    per_device_train_batch_size=4,
    gradient_accumulation_steps=4,
    # num of initial training steps
    warmup_steps=2,
    # total number of training steps
    max_steps=1800,
    learning_rate=2e-4,
    fp16=not is_bfloat16_supported(),
    bf16=is_bfloat16_supported(),
    # controls how often training metrics like loss are logged during the process
    logging_steps=1,
    optim="adamw_8bit",
    # introduces a penalty term that discourages large weights in the model,
    # helping to prevent overfitting
    weight_decay=0.01,
    # the learning rate scheduler that controls how the learning rate changes throughout training
    # "linear" suggests a linear warmup followed by a linear decrease to zero.
    lr_scheduler_type="linear",
    output_dir="outputs",
    seed=42,
)

# %%
trainer = SFTTrainer(
    model=model,
    tokenizer=tokenizer,
    train_dataset=dataset["train"],
    eval_dataset=dataset["eval"],
    dataset_text_field="Prompt",
    # sequences exceeding this length will be truncated
    max_seq_length=max_seq_length,
    # the number of processes used to prepare the training data for faster loading
    dataset_num_proc=2,
    packing=False,  # can make training 5x faster for short sequences.
    args=training_args,
)
# Out:
# /usr/local/lib/python3.10/dist-packages/multiprocess/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# Map (num_proc=2):   0%|          | 0/70317 [00:00<?, ? examples/s]
# Map (num_proc=2):   0%|          | 0/3907 [00:00<?, ? examples/s]
# max_steps is given, it will override any value given in num_train_epochs

# %% [markdown]
# ### train

# %%
trainer_stats = trainer.train()
# Out:
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs = 1
#    \\   /|    Num examples = 70,317 | Num Epochs = 1
# O^O/ \_/ \    Batch size per device = 4 | Gradient Accumulation steps = 4
# \        /    Total batch size = 16 | Total steps = 1,800
#  "-____-"     Number of trainable parameters = 39,223,296
#     <div>
#
#       <progress value='1800' max='1800' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1800/1800 54:25, Epoch 0/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.920600</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.734400</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.142400</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.846000</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.967400</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.076500</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.826100</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.922600</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.850600</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.865700</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.922100</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.695300</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.807900</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.782100</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.623400</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.995100</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>1.127700</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>1.045900</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.762000</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.957200</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.790300</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.815200</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>1.096300</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.712400</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.954400</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>1.421900</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.572700</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>1.069700</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.933900</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.864200</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>0.891600</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>0.819700</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>0.835900</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>0.583700</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>0.970400</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>1.051700</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>1.060200</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>0.518200</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>0.917500</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.918600</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>0.670300</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>0.629000</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>0.868200</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>0.931400</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>0.850600</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>0.926500</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>1.177400</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>0.911300</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>0.669400</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.790900</td>
#     </tr>
#     <tr>
#       <td>51</td>
#       <td>0.887100</td>
#     </tr>
#     <tr>
#       <td>52</td>
#       <td>1.029700</td>
#     </tr>
#     <tr>
#       <td>53</td>
#       <td>1.109700</td>
#     </tr>
#     <tr>
#       <td>54</td>
#       <td>0.749600</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>0.568800</td>
#     </tr>
#     <tr>
#       <td>56</td>
#       <td>1.107900</td>
#     </tr>
#     <tr>
#       <td>57</td>
#       <td>0.790900</td>
#     </tr>
#     <tr>
#       <td>58</td>
#       <td>0.920700</td>
#     </tr>
#     <tr>
#       <td>59</td>
#       <td>1.022100</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>0.753600</td>
#     </tr>
#     <tr>
#       <td>61</td>
#       <td>0.905200</td>
#     </tr>
#     <tr>
#       <td>62</td>
#       <td>0.842100</td>
#     </tr>
#     <tr>
#       <td>63</td>
#       <td>0.705600</td>
#     </tr>
#     <tr>
#       <td>64</td>
#       <td>0.930300</td>
#     </tr>
#     <tr>
#       <td>65</td>
#       <td>0.917900</td>
#     </tr>
#     <tr>
#       <td>66</td>
#       <td>0.732100</td>
#     </tr>
#     <tr>
#       <td>67</td>
#       <td>0.743700</td>
#     </tr>
#     <tr>
#       <td>68</td>
#       <td>0.907900</td>
#     </tr>
#     <tr>
#       <td>69</td>
#       <td>0.660100</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>0.828000</td>
#     </tr>
#     <tr>
#       <td>71</td>
#       <td>0.815500</td>
#     </tr>
#     <tr>
#       <td>72</td>
#       <td>0.610100</td>
#     </tr>
#     <tr>
#       <td>73</td>
#       <td>0.930600</td>
#     </tr>
#     <tr>
#       <td>74</td>
#       <td>0.777900</td>
#     </tr>
#     <tr>
#       <td>75</td>
#       <td>1.153200</td>
#     </tr>
#     <tr>
#       <td>76</td>
#       <td>1.127400</td>
#     </tr>
#     <tr>
#       <td>77</td>
#       <td>0.818100</td>
#     </tr>
#     <tr>
#       <td>78</td>
#       <td>0.596500</td>
#     </tr>
#     <tr>
#       <td>79</td>
#       <td>0.971200</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>0.705600</td>
#     </tr>
#     <tr>
#       <td>81</td>
#       <td>0.895300</td>
#     </tr>
#     <tr>
#       <td>82</td>
#       <td>0.897600</td>
#     </tr>
#     <tr>
#       <td>83</td>
#       <td>0.802700</td>
#     </tr>
#     <tr>
#       <td>84</td>
#       <td>1.009600</td>
#     </tr>
#     <tr>
#       <td>85</td>
#       <td>0.903700</td>
#     </tr>
#     <tr>
#       <td>86</td>
#       <td>0.941100</td>
#     </tr>
#     <tr>
#       <td>87</td>
#       <td>0.609100</td>
#     </tr>
#     <tr>
#       <td>88</td>
#       <td>0.827400</td>
#     </tr>
#     <tr>
#       <td>89</td>
#       <td>0.796200</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>0.696600</td>
#     </tr>
#     <tr>
#       <td>91</td>
#       <td>0.791500</td>
#     </tr>
#     <tr>
#       <td>92</td>
#       <td>0.702700</td>
#     </tr>
#     <tr>
#       <td>93</td>
#       <td>0.683300</td>
#     </tr>
#     <tr>
#       <td>94</td>
#       <td>1.051000</td>
#     </tr>
#     <tr>
#       <td>95</td>
#       <td>0.546400</td>
#     </tr>
#     <tr>
#       <td>96</td>
#       <td>0.738800</td>
#     </tr>
#     <tr>
#       <td>97</td>
#       <td>1.014600</td>
#     </tr>
#     <tr>
#       <td>98</td>
#       <td>0.948700</td>
#     </tr>
#     <tr>
#       <td>99</td>
#       <td>0.837700</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.394300</td>
#     </tr>
#     <tr>
#       <td>101</td>
#       <td>1.706000</td>
#     </tr>
#     <tr>
#       <td>102</td>
#       <td>1.051900</td>
#     </tr>
#     <tr>
#       <td>103</td>
#       <td>0.597800</td>
#     </tr>
#     <tr>
#       <td>104</td>
#       <td>0.865800</td>
#     </tr>
#     <tr>
#       <td>105</td>
#       <td>0.979300</td>
#     </tr>
#     <tr>
#       <td>106</td>
#       <td>1.247400</td>
#     </tr>
#     <tr>
#       <td>107</td>
#       <td>0.625800</td>
#     </tr>
#     <tr>
#       <td>108</td>
#       <td>0.932300</td>
#     </tr>
#     <tr>
#       <td>109</td>
#       <td>0.935300</td>
#     </tr>
#     <tr>
#       <td>110</td>
#       <td>0.425300</td>
#     </tr>
#     <tr>
#       <td>111</td>
#       <td>0.756600</td>
#     </tr>
#     <tr>
#       <td>112</td>
#       <td>0.615300</td>
#     </tr>
#     <tr>
#       <td>113</td>
#       <td>1.317200</td>
#     </tr>
#     <tr>
#       <td>114</td>
#       <td>0.879500</td>
#     </tr>
#     <tr>
#       <td>115</td>
#       <td>0.651500</td>
#     </tr>
#     <tr>
#       <td>116</td>
#       <td>0.833100</td>
#     </tr>
#     <tr>
#       <td>117</td>
#       <td>0.433300</td>
#     </tr>
#     <tr>
#       <td>118</td>
#       <td>0.863700</td>
#     </tr>
#     <tr>
#       <td>119</td>
#       <td>1.047400</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>0.637000</td>
#     </tr>
#     <tr>
#       <td>121</td>
#       <td>1.160100</td>
#     </tr>
#     <tr>
#       <td>122</td>
#       <td>0.761100</td>
#     </tr>
#     <tr>
#       <td>123</td>
#       <td>0.798700</td>
#     </tr>
#     <tr>
#       <td>124</td>
#       <td>0.620600</td>
#     </tr>
#     <tr>
#       <td>125</td>
#       <td>0.830200</td>
#     </tr>
#     <tr>
#       <td>12
# /usr/local/lib/python3.10/dist-packages/peft/utils/other.py:611: UserWarning: Unable to fetch remote file due to the following error 401 Client Error. (Request ID: Root=1-665807d4-1037866f1ef673555b823e35;e118a6ff-e6c0-499d-a717-30b6825799d9)
#
# Cannot access gated repo for url https://huggingface.co/google/gemma-2b/resolve/main/config.json.
# Access to model google/gemma-2b is restricted. You must be authenticated to access it. - silently ignoring the lookup for the file config.json in google/gemma-2b.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/peft/utils/save_and_load.py:195: UserWarning: Could not find a config file in google/gemma-2b - will assume that the vocabulary was not modified.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/peft/utils/other.py:611: UserWarning: Unable to fetch remote file due to the following error 401 Client Error. (Request ID: Root=1-66580b67-4b44ea5c238e8f4659f7cec3;aaee8a8d-c3d3-436c-9412-9cc14aed4158)
#
# Cannot access gated repo for url https://huggingface.co/google/gemma-2b/resolve/main/config.json.
# Access to model google/gemma-2b is restricted. You must be authenticated to access it. - silently ignoring the lookup for the file config.json in google/gemma-2b.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/peft/utils/save_and_load.py:195: UserWarning: Could not find a config file in google/gemma-2b - will assume that the vocabulary was not modified.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/peft/utils/other.py:611: UserWarning: Unable to fetch remote file due to the following error 401 Client Error. (Request ID: Root=1-66580ee8-4821d8440f330d545d5823b0;faf2330a-6255-434a-b5f7-2024fd9f8773)
#
# Cannot access gated repo for url https://huggingface.co/google/gemma-2b/resolve/main/config.json.
# Access to model google/gemma-2b is restricted. You must be authenticated to access it. - silently ignoring the lookup for the file config.json in google/gemma-2b.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/peft/utils/save_and_load.py:195: UserWarning: Could not find a config file in google/gemma-2b - will assume that the vocabulary was not modified.
#   warnings.warn(

# %% [markdown]
# ### Stats

# %%
# training stats
trainer_stats.metrics
# Out:
# {'train_runtime': 3267.433,
#  'train_samples_per_second': 8.814,
#  'train_steps_per_second': 0.551,
#  'total_flos': 5.611296338672026e+16,
#  'train_loss': 0.7452311797440052,
#  'epoch': 0.40955631399317405}

# %% [markdown]
# # Inference/Prediction

# %%
from tqdm import tqdm

# %%
# checking out specific rows in `test` set
print("TEST:\n", dataset["test"][7]["Prompt"])
print("TEST EMOTION:\n", dataset["test"][7]["Emotion"])

print()

print("TEST:\n", dataset["test"][10]["Prompt"])
print("TEST EMOTION:\n", dataset["test"][10]["Emotion"])
# Out:
# TEST:
#  Analyze the emotion of the text enclosed in square brackets,
# determine if it is Happy, Love, Sadness, Anger or Fear, and return the answer only as
# the corresponding sentiment label 'Happy' or 'Love' or 'Sadness' or 'Anger' or 'Fear'
#
# [The product works pretty well, but wasn't expecting such a small bottle. Over all good product. Been using it for three days.] =
# TEST EMOTION:
#  Sadness
#
# TEST:
#  Analyze the emotion of the text enclosed in square brackets,
# determine if it is Happy, Love, Sadness, Anger or Fear, and return the answer only as
# the corresponding sentiment label 'Happy' or 'Love' or 'Sadness' or 'Anger' or 'Fear'
#
# [Good and as usual just like other mid-range brands, nothing special to talk about.] =
# TEST EMOTION:
#  Happy

# %%
prompt = dataset["test"][7]["Prompt"]
#prompt = """Analyze the emotion of the text enclosed in square brackets,
#determine if it is Happy, Love, Sadness, Anger or Fear, and return the answer only as
#the corresponding sentiment label 'Happy' or 'Love' or 'Sadness' or 'Anger' or 'Fear'
#
#[খারাপ না তেমন] = """.strip()

# tokenize the prompt
inputs = tokenizer([prompt], return_tensors="pt").to("cuda")
# generate the output using the tokenized prompt
output = model.generate(
    **inputs,
    max_new_tokens=2,
    # no randomness
    temperature=0.0,
    use_cache=True,
)

result = tokenizer.decode(output[0])

print(result)
# Out:
# <bos>Analyze the emotion of the text enclosed in square brackets,
# determine if it is Happy, Love, Sadness, Anger or Fear, and return the answer only as
# the corresponding sentiment label 'Happy' or 'Love' or 'Sadness' or 'Anger' or 'Fear'
#
# [The product works pretty well, but wasn't expecting such a small bottle. Over all good product. Been using it for three days.] = Happy

# %% [markdown]
# ## Predict on test set

# %%
def predict(test_set, model, tokenizer):
    test_set_preds = []
    labels = ["Happy", "Love", "Sadness", "Anger", "Fear", "None"]

    # enable native 2x faster inference
    FastLanguageModel.for_inference(model)

    for i in tqdm(range(len(test_set))):
        prompt = test_set.iloc[i]["Prompt"]

        input_ids = tokenizer(prompt, return_tensors="pt").to("cuda")
        outputs = model.generate(
            **input_ids,
            pad_token_id=tokenizer.eos_token_id,
            max_new_tokens=2,
            temperature=0.0,
        )
        result = tokenizer.decode(outputs[0])
        # take the emotion part of the decoded string
        answer = result.split("=")[-1].lower()

        if labels[0].lower() in answer:
            test_set_preds.append(labels[0])
        elif labels[1].lower() in answer:
            test_set_preds.append(labels[1])
        elif labels[2].lower() in answer:
            test_set_preds.append(labels[2])
        elif labels[3].lower() in answer:
            test_set_preds.append(labels[3])
        elif labels[4].lower() in answer:
            test_set_preds.append(labels[4])
        elif labels[5].lower() in answer:
            test_set_preds.append(labels[5])
        else:
            test_set_preds.append("None")

        # print for first 10 iterations
        if i < 10:
            print(test_set_preds)

    return test_set_preds

# %%
test_set_preds = predict(dataset["test"].to_pandas(), model, tokenizer)
# Out:
#   0%|          | 2/3906 [00:00<20:24,  3.19it/s]
# ['Happy']
# ['Happy', 'Happy']
#   0%|          | 4/3906 [00:01<15:06,  4.31it/s]
# ['Happy', 'Happy', 'Happy']
# ['Happy', 'Happy', 'Happy', 'Happy']
#   0%|          | 6/3906 [00:01<13:33,  4.79it/s]
# ['Happy', 'Happy', 'Happy', 'Happy', 'Love']
# ['Happy', 'Happy', 'Happy', 'Happy', 'Love', 'Happy']
#   0%|          | 7/3906 [00:01<13:07,  4.95it/s]
# ['Happy', 'Happy', 'Happy', 'Happy', 'Love', 'Happy', 'Happy']
#   0%|          | 9/3906 [00:02<12:58,  5.01it/s]
# ['Happy', 'Happy', 'Happy', 'Happy', 'Love', 'Happy', 'Happy', 'Happy']
# ['Happy', 'Happy', 'Happy', 'Happy', 'Love', 'Happy', 'Happy', 'Happy', 'Happy']
#   0%|          | 10/3906 [00:02<12:37,  5.14it/s]
# ['Happy', 'Happy', 'Happy', 'Happy', 'Love', 'Happy', 'Happy', 'Happy', 'Happy', 'Sadness']
# 100%|██████████| 3906/3906 [09:50<00:00,  6.62it/s]

# %%
# unique values that the model predicted from `test` set
set(test_set_preds)
# Out:
# {'Anger', 'Happy', 'Love', 'Sadness'}

# %% [markdown]
# # Evaluation

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
evaluation_stats = trainer.evaluate()
# Out:
#     <div>
#
#       <progress value='489' max='489' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [489/489 03:13]
#     </div>

# %%
# evaluation stats
evaluation_stats
# Out:
# {'eval_loss': 0.9215754270553589,
#  'eval_runtime': 193.4856,
#  'eval_samples_per_second': 20.193,
#  'eval_steps_per_second': 2.527,
#  'epoch': 0.40955631399317405}

# %%
def evaluate(test_labels, test_predictions):
    mapping = {"Happy": 5, "Love": 4, "Sadness": 3, "Anger": 2, "Fear": 1, "None": 0}

    def map_func(x):
        # returns the corresponding int from the mapping.
        # if no label found return 0
        return mapping.get(x, 0)

    # map the string values in the labels and predictions to integer
    test_labels = np.vectorize(map_func)(test_labels)
    test_predictions = np.vectorize(map_func)(test_predictions)

    accuracy = accuracy_score(y_true=test_labels, y_pred=test_predictions)
    print(f"Accuracy: {accuracy}")

    # Generate classification report
    class_report = classification_report(
        y_true=test_labels,
        y_pred=test_predictions,
        target_names=[
            "Fear: 1",
            "Anger: 2",
            "Sadness: 3",
            "Love: 4",
            "Happy: 5",
        ],
        # if there are no prediction of a specific label, do not show any errors
        zero_division=0,
    )
    print("\nClassification Report:")
    print(class_report)

    # generate confusion matrix
    conf_matrix = confusion_matrix(
        y_true=test_labels, y_pred=test_predictions, labels=[1, 2, 3, 4, 5]
    )
    print("\nConfusion Matrix:")
    print(conf_matrix)

# %%
test_set_labels = dataset["test"].to_pandas()["Emotion"]

evaluate(test_set_labels, test_set_preds)
# Out:
# Accuracy: 0.7117255504352279
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Fear: 1       0.00      0.00      0.00        58
#     Anger: 2       0.73      0.52      0.61       159
#   Sadness: 3       0.55      0.66      0.60       326
#      Love: 4       0.68      0.40      0.50      1031
#     Happy: 5       0.74      0.89      0.81      2332
#
#     accuracy                           0.71      3906
#    macro avg       0.54      0.49      0.50      3906
# weighted avg       0.70      0.71      0.69      3906
#
#
# Confusion Matrix:
# [[   0    6   32    0   20]
#  [   0   83   60    1   15]
#  [   0   20  214    1   91]
#  [   0    2   18  408  603]
#  [   0    2   66  189 2075]]

# %% [markdown]
# # Saving, loading finetuned models
# This only saves the LoRA adapters, and not the full model.

# %%
# local saving
model.save_pretrained("./model")
tokenizer.save_pretrained("./model")

# online saving
# model.push_to_hub("your_name/lora_model", token = "...")
# tokenizer.push_to_hub("your_name/lora_model", token = "...")
# Out:
# /usr/local/lib/python3.10/dist-packages/peft/utils/other.py:611: UserWarning: Unable to fetch remote file due to the following error 401 Client Error. (Request ID: Root=1-66581578-465e993a760baf590c28c51a;783fab8b-7e2a-4add-9a23-df2681007b1d)
#
# Cannot access gated repo for url https://huggingface.co/google/gemma-2b/resolve/main/config.json.
# Access to model google/gemma-2b is restricted. You must be authenticated to access it. - silently ignoring the lookup for the file config.json in google/gemma-2b.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/peft/utils/save_and_load.py:195: UserWarning: Could not find a config file in google/gemma-2b - will assume that the vocabulary was not modified.
#   warnings.warn(
# ('./model/tokenizer_config.json',
#  './model/special_tokens_map.json',
#  './model/tokenizer.model',
#  './model/added_tokens.json',
#  './model/tokenizer.json')

# %%
# create an archive of the finetuned model
# !tar -czvf emotion_analysis_gemma_2b__v3.4.0__safetensors.tar.gz /content/model
# Out:
# tar: Removing leading `/' from member names
# /content/model/
# /content/model/tokenizer.json
# /content/model/README.md
# /content/model/special_tokens_map.json
# /content/model/tokenizer.model
# /content/model/tokenizer_config.json
# /content/model/adapter_model.safetensors
# /content/model/adapter_config.json

# %%
# for loading previously saved lora adaptors
if False:
    from unsloth import FastLanguageModel

    model, tokenizer = FastLanguageModel.from_pretrained(
        model_name="./model",
        max_seq_length=max_seq_length,
        dtype=dtype,
        load_in_4bit=load_in_4bit,
    )
    # enable native 2x faster inference
    FastLanguageModel.for_inference(model)


prompt = dataset["test"][7]["Prompt"]

# tokenize the prompt
inputs = tokenizer([prompt], return_tensors="pt").to("cuda")
# generate the output using the tokenized prompt
output = model.generate(
    **inputs,
    # pad_token_id=tokenizer.eos_token_id,
    max_new_tokens=2,
    # no randomness
    temperature=0.0,
    use_cache=True,
)

result = tokenizer.decode(output[0])

print(result)
# Out:
# <bos>Analyze the emotion of the text enclosed in square brackets,
# determine if it is Happy, Love, Sadness, Anger or Fear, and return the answer only as
# the corresponding sentiment label 'Happy' or 'Love' or 'Sadness' or 'Anger' or 'Fear'
#
# [The product works pretty well, but wasn't expecting such a small bottle. Over all good product. Been using it for three days.] = Happy

# %% [markdown]
# # GGUF / llama.cpp Conversion
# * `q8_0` - Fast conversion. High resource use, but generally acceptable.
# * `q4_k_m` - Recommended. Uses Q6_K for half of the attention.wv and feed_forward.w2 tensors, else Q4_K.
# * `q5_k_m` - Recommended. Uses Q6_K for half of the attention.wv and feed_forward.w2 tensors, else Q5_K.

# %%
# save to q4_k_m GGUF
if True:
    model.save_pretrained_gguf("model", tokenizer, quantization_method="q4_k_m")

if False:
    model.push_to_hub_gguf(
        "hf/model", tokenizer, quantization_method="q4_k_m", token=""
    )

# save to q5_k_m GGUF
if False:
    model.push_to_hub_gguf(
        "hf/model", tokenizer, quantization_method="q5_k_m", token=""
    )
# Out:
# Unsloth: Merging 4bit and LoRA weights to 16bit...
# Unsloth: Will use up to 6.76 out of 12.67 RAM for saving.
# 100%|██████████| 18/18 [00:01<00:00, 11.90it/s]
# Unsloth: Saving tokenizer... Done.
# Unsloth: Saving model... This might take 5 minutes for Llama-7b...
# Unsloth: Saving model/pytorch_model-00001-of-00002.bin...
# Unsloth: Saving model/pytorch_model-00002-of-00002.bin...
# Done.
# ==((====))==  Unsloth: Conversion from QLoRA to GGUF information
#    \\   /|    [0] Installing llama.cpp will take 3 minutes.
# O^O/ \_/ \    [1] Converting HF to GUUF 16bits will take 3 minutes.
# \        /    [2] Converting GGUF 16bits to q4_k_m will take 20 minutes.
#  "-____-"     In total, you will have to wait around 26 minutes.
#
# Unsloth: [0] Installing llama.cpp. This will take 3 minutes...
# Unsloth: [1] Converting model at model into f16 GGUF format.
# The output location will be ./model-unsloth.F16.gguf
# This will take 3 minutes...
# INFO:hf-to-gguf:Loading model: model
# INFO:gguf.gguf_writer:gguf: This GGUF file is for Little Endian only
# INFO:hf-to-gguf:Set model parameters
# INFO:hf-to-gguf:Set model tokenizer
# INFO:gguf.vocab:Setting special token type bos to 2
# INFO:gguf.vocab:Setting special token type eos to 1
# INFO:gguf.vocab:Setting special token type unk to 3
# INFO:gguf.vocab:Setting special token type pad to 1
# INFO:gguf.vocab:Setting add_bos_token to True
# INFO:gguf.vocab:Setting add_eos_token to False
# INFO:gguf.vocab:Setting special token type prefix to 67
# INFO:gguf.vocab:Setting special token type suffix to 69
# INFO:gguf.vocab:Setting special token type middle to 68
# WARNING:gguf.vocab:No handler for special token type fsep with id 70 - skipping
# INFO:gguf.vocab:Setting special token type eot to 107
# INFO:hf-to-gguf:Exporting model to 'model-unsloth.F16.gguf'
# INFO:hf-to-gguf:gguf: loading model weight map from 'pytorch_model.bin.index.json'
# INFO:hf-to-gguf:gguf: loading model part 'pytorch_model-00001-of-00002.bin'
# INFO:hf-to-gguf:token_embd.weight,         torch.float16 --> F16, shape = {2048, 256000}
# INFO:hf-to-gguf:blk.0.attn_q.weight,       torch.float16 --> F16, shape = {2048, 2048}
# INFO:hf-to-gguf:blk.0.attn_k.weight,       torch.float16 --> F16, shape = {2048, 256}
# INFO:hf-to-gguf:blk.0.attn_v.weight,       torch.float16 --> F16, shape = {2048, 256}
# INFO:hf-to-gguf:blk.0.attn_output.weight,  torch.float16 --> F16, shape = {2048, 2048}
# INFO:hf-to-gguf:blk.0.ffn_gate.weight,     torch.float16 --> F16, shape = {2048, 16384}
# INFO:hf-to-gguf:blk.0.ffn_up.weight,       torch.float16 --> F16, shape = {2048, 16384}
# INFO:hf-to-gguf:blk.0.ffn_down.weight,     torch.float16 --> F16, shape = {16384, 2048}
# INFO:hf-to-gguf:blk.0.attn_norm.weight,    torch.float16 --> F32, shape = {2048}
# INFO:hf-to-gguf:blk.0.ffn_norm.weight,     torch.float16 --> F32, shape = {2048}
# INFO:hf-to-gguf:blk.1.attn_q.weight,       torch.float16 --> F16, shape = {2048, 2048}
# INFO:hf-to-gguf:blk.1.attn_k.weight,       torch.float16 --> F16, shape = {2048, 256}
# INFO:hf-to-gguf:blk.1.attn_v.weight,       torch.float16 --> F16, shape = {2048, 256}
# INFO:hf-to-gguf:blk.1.attn_output.weight,  torch.float16 --> F16, shape = {2048, 2048}
# INFO:hf-to-gguf:blk.1.ffn_gate.weight,     torch.float16 --> F16, shape = {2048, 16384}
# INFO:hf-to-gguf:blk.1.ffn_up.weight,       torch.float16 --> F16, shape = {2048, 16384}
# INFO:hf-to-gguf:blk.1.ffn_down.weight,     torch.float16 --> F16, shape = {16384, 2048}
# INFO:hf-to-gguf:blk.1.attn_norm.weight,    torch.float16 --> F32, shape = {2048}
# INFO:hf-to-gguf:blk.1.ffn_norm.weight,     torch.float16 --> F32, shape = {2048}
# INFO:hf-to-gguf:blk.2.attn_q.weight,       torch.float16 --> F16, shape = {2048, 2048}
# INFO:hf-to-gguf:blk.2.attn_k.weight,       torch.float16 --> F16, shape = {2048, 256}
# INFO:hf-to-gguf:blk.2.attn_v.weight,       torch.float16 --> F16, shape = {2048, 256}
# INFO:hf-to-gguf:blk.2.attn_output.weight,  torch.float16 --> F16, shape = {2048, 2048}
# INFO:hf-to-gguf:blk.2.ffn_gate.weight,     torch.float16 --> F16, shape = {2048, 16384}
# INFO:hf-to-gguf:blk.2.ffn_up.weight,       torch.float16 --> F16, shape = {2048, 16384}
# INFO:hf-to-gguf:blk.2.ffn_down.weight,     torch.float16 --> F16, shape = {16384, 2048}
# INFO:hf-to-gguf:blk.2.attn_norm.weight,    torch.float16 --> F32, shape = {2048}
# INFO:hf-to-gguf:blk.2.ffn_norm.weight,     torch.float16 --> F32, shape = {2048}
# INFO:hf-to-gguf:blk.3.attn_q.weight,       torch.float16 --> F16, shape = {2048, 2048}
# INFO:hf-to-gguf:blk.3.attn_k.weight,       torch.float16 --> F16, shape = {2048, 256}
# INFO:hf-to-gguf:blk.3.attn_v.weight,       torch.float16 --> F16, shape = {2048, 256}
# INFO:hf-to-gguf:blk.3.attn_output.weight,  torch.float16 --> F16, shape = {2048, 2048}
# INFO:hf-to-gguf:blk.3.ffn_gate.weight,     torch.float16 --> F16, shape = {2048, 16384}
# INFO:hf-to-gguf:blk.3.ffn_up.weight,       torch.float16 --> F16, shape = {2048, 16384}
# INFO:hf-to-gguf:blk.3.ffn_down.weight,     torch.float16 --> F16, shape = {16384, 2048}
# INFO:hf-to-gguf:blk.3.attn_norm.weight,    torch.float16 --> F32, shape = {2048}
# INFO:hf-to-gguf:blk.3.ffn_norm.weight,     torch.float16 --> F32, shape = {2048}
# INFO:hf-to-gguf:blk.4.attn_q.weight,       torch.float16 --> F16, shape = {2048, 2048}
# INFO:hf-to-gguf:blk.4.attn_k.weight,       torch.float16 --> F16, shape = {2048, 256}
# INFO:hf-to-gguf:blk.4.attn_v.weight,       torch.float16 --> F16, shape = {2048, 256}
# INFO:hf-to-gguf:blk.4.attn_output.weight,  torch.float16 --> F16, shape = {2048, 2048}
# INFO:hf-to-gguf:blk.4.ffn_gate.weight,     torch.float16 --> F16, shape = {2048, 16384}
# INFO:hf-to-gguf:blk.4.ffn_up.weight,       torch.float16 --> F16, shape = {2048, 16384}
# INFO:hf-to-gguf:blk.4.ffn_down.weight,     torch.float16 --> F16, shape = {16384, 2048}
# INFO:hf-to-gguf:blk.4.attn_norm.weight,    torch.float16 --> F32, shape = {2048}
# INFO:hf-to-gguf:blk.4.ffn_norm.weight,     torch.float16 --> F32, shape = {2048}
# INFO:hf-to-gguf:blk.5.attn_q.weight,       torch.float16 --> F16, shape = {2048, 2048}
# INFO:hf-to-gguf:blk.5.attn_k.weight,       torch.float16 --> F16, shape = {2048, 256}
# INFO:hf-to-gguf:blk.5.attn_v.weight,       torch.float16 --> F16, shape = {2048, 256}
# INFO:hf-to-gguf:blk.5.attn_output.weight,  torch.float16 --> F16, shape = {2048, 2048}
# INFO:hf-to-gguf:blk.5.ffn_gate.weight,     torch.float16 --> F16, shape = {2048, 16384}
# INFO:hf-to-gguf:blk.5.ffn_up.weight,       torch.float16 --> F16, shape = {2048, 16384}
# INFO:hf-to-gguf:blk.5.ffn_down.weight,     torch.float16 --> F16, shape = {16384, 2048}
# INFO:hf-to-gguf:blk.5.attn_norm.weight,    torch.float16 --> F32, shape = {2048}
# INFO:hf-to-gguf:blk.5.ffn_norm.weight,     torch.float16 --> F32, shape = {2048}
# INFO:hf-to-gguf:blk.6.attn_q.weight,       torch.float16 --> F16, shape = {2048, 2048}
# INFO:hf-to-gguf:blk.6.attn_k.weight,       torch.float16 --> F16, shape = {2048, 256}
# INFO:hf-to-gguf:blk.6.attn_v.weight,       torch.float16 --> F16, shape = {2048, 256}
# INFO:hf-to-gguf:blk.6.attn_output.weight,  torch.float16 --> F16, shape = {2048, 2048}
# INFO:hf-to-gguf:blk.6.ffn_gate.weight,     torch.float16 --> F16, shape = {2048, 16384}
# INFO:hf-to-gguf:blk.6.ffn_up.weight,       torch.float16 --> F16, shape = {2048, 16384}
# INFO:hf-to-gguf:blk.6.ffn_down.weight,     torch.float16 --> F16, shape = {16384, 2048}
# INFO:hf-to-gguf:blk.6.attn_norm.weight,    torch.float16 --> F32, shape = {2048}
# INFO:hf-to-gguf:blk.6.ffn_norm.weight,     torch.float16 --> F32, shape = {2048}
# INFO:hf-to-gguf:blk.7.attn_q.weight,       torch.float16 --> F16, shape = {2048, 2048}
# INFO:hf-to-gguf:blk.7.attn_k.weight,       torch.float16 --> F16, shape = {2048, 256}
# INFO:hf-to-gguf:blk.7.attn_v.weight,       torch.float16 --> F16, shape = {2048, 256}
# INFO:hf-to-gguf:blk.7.attn_output.weight,  torch.float16 --> F16, shape = {2048, 2048}
# INFO:hf-to-gguf:blk.7.ffn_gate.weight,     torch.float16 --> F16, shape = {2048, 16384}
# INFO:hf-to-gguf:blk.7.ffn_up.weight,       torch.float16 --> F16, shape = {2048, 16384}
# INFO:hf-to-gguf:blk.7.ffn_down.weight,     torch.float16 --> F16, shape = {16384, 2048}
# INFO:hf-to-gguf:blk.7.attn_norm.weight,    torch.float16 --> F32, shape = {2048}
# INFO:hf-to-gguf:blk.7.ffn_norm.weight,     torch.float16 --> F32, shape = {2048}
# INFO:hf-to-gguf:blk.8.attn_q.weight,       torch.float16 --> F16, shape = {2048, 2048}
# INFO:hf-to-gguf:blk.8.attn_k.weight,       torch.float16 --> F16, shape = {2048, 256}
# INFO:hf-to-gguf:blk.8.attn_v.weight,       torch.float16 --> F16, shape = {2048, 256}
# INFO:hf-to-gguf:blk.8.attn_output.weight,  torch.float16 --> F16, shape = {2048, 2048}
# INFO:hf-to-gguf:blk.8.ffn_gate.weight,     torch.float16 --> F16, shape = {2048, 16384}
# INFO:hf-to-gguf:blk.8.ffn_up.weight,       torch.float16 --> F16, shape = {2048, 16384}
# INFO:hf-to-gguf:blk.8.ffn_down.weight,     torch.float16 --> F16, shape = {16384, 2048}
# INFO:hf-to-gguf:blk.8.attn_norm.weight,    torch.float16 --> F32, shape = {2048}
# INFO:hf-to-gguf:blk.8.ffn_norm.weight,     torch.float16 --> F32, shape = {2048}
# INFO:hf-to-gguf:blk.9.attn_q.weight,       torch.float16 --> F16, shape = {2048, 2048}
# INFO:hf-to-gguf:blk.9.attn_k.weight,       torch.float16 --> F16, shape = {2048, 256}
# INFO:hf-to-gguf:blk.9.attn_v.weight,       torch.float16 --> F16, shape = {2048, 256}
# INFO:hf-to-gguf:blk.9.attn_output.weight,  torch.float16 --> F16, shape = {2048, 2048}
# INFO:hf-to-gguf:blk.9.ffn_gate.weight,     torch.float16 --> F16, shape = {2048, 16384}
# INFO:hf-to-gguf:blk.9.ffn_up.weight,       torch.float16 --> F16, shape = {2048, 16384}
# INFO:hf-to-gguf:blk.9.ffn_down.weight,     torch.float16 --> F16, shape = {16384, 2048}
# INFO:hf-to-gguf:blk.9.attn_norm.weight,    torch.float16 --> F32, shape = {2048}
# INFO:hf-to-gguf:blk.9.ffn_norm.weight,     torch.float16 --> F32, shape = {2048}
# INFO:hf-to-gguf:blk.10.attn_q.weight,      torch.float16 --> F16, shape = {2048, 2048}
# INFO:hf-to-gguf:blk.10.attn_k.weight,      torch.float16 --> F16, shape = {2048, 256}
# INFO:hf-to-gguf:blk.10.attn_v.weight,      torch.float16 --> F16, shape = {2048, 256}
# INFO:hf-to-gguf:blk.10.attn_output.weight, torch.float16 --> F16, shape = {2048, 2048}
# INFO:hf-to-gguf:blk.10.ffn_gate.weight,    torch.float16 --> F16, shape = {2048, 16384}
# INFO:hf-to-gguf:blk.10.ffn_up.weight,      torch.float16 --> F16, shape = {2048, 16384}
# INFO:hf-to-gguf:blk.10.ffn_down.weight,    torch.float16 --> F16, shape = {16384, 2048}
# INFO:hf-to-gguf:blk.10.attn_norm.weight,   torch.float16 --> F32, shape = {2048}
# INFO:hf-to-gguf:blk.10.ffn_norm.weight,    torch.float16 --> F32, shape = {2048}
# INFO:hf-to-gguf:blk.11.attn_q.weight,      torch.float16 --> F16, shape = {2048, 2048}
# INFO:hf-to-gguf:blk.11.attn_k.weight,      torch.float16 --> F16, shape = {2048, 256}
# INFO:hf-to-gguf:blk.11.attn_v.weight,      torch.float16 --> F16, shape = {2048, 256}
# INFO:hf-to-gguf:blk.11.attn_output.weight, torch.float16 --> F16, shape = {2048, 2048}
# INFO:hf-to-gguf:blk.11.ffn_gate.weight,    torch.float16 --> F16, shape = {2048, 16384}
# INFO:hf-to-gguf:blk.11.ffn_up.weight,      torch.float16 --> F16, shape = {2048, 16384}
# INFO:hf-to-gguf:blk.11.ffn_down.weight,    torch.float16 --> F16, shape = {16384, 2048}
# INFO:hf-to-gguf:blk.11.attn_norm.weight,   torch.float16 --> F32, shape = {2048}
# INFO:hf-to-gguf:blk.11.ffn_norm.weight,    torch.float16 --> F32, shape = {2048}
# INFO:hf-to-gguf:blk.12.attn_q.weight,      torch.float16 --> F16, shape = {2048, 2048}
# INFO:hf-to-gguf:blk.12.attn_k.weight,      torch.float16 --> F16, shape = {2048, 256}
# INFO:hf-to-gguf:blk.12.attn_v.weight,      torch.float16 --> F16, shape = {2048, 256}
# INFO:hf-to-gguf:blk.12.attn_output.weight, torch.float16 --> F16, shape = {2048, 2048}
# INFO:hf-to-gguf:blk.12.ffn_gate.weight,    torch.float16 --> F16, shape = {2048, 16384}
# INFO:hf-to-gguf:blk.12.ffn_up.weight,      torch.float16 --> F16, shape = {2048, 16384}
# INFO:hf-to-gguf:blk.12.ffn_down.weight,    torch.float16 --> F16, shape = {16384, 2048}
# INFO:hf-to-gguf:blk.12.attn_norm.weight,   torch.float16 --> F32, shape = {2048}
# INFO:hf-to-gguf:blk.12.ffn_norm.weight,    torch.float16 --> F32, shape = {2048}
# INFO:hf-to-gguf:blk.13.attn_q.weight,      torch.float16 --> F16, shape = {2048, 2048}
# INFO:hf-to-gguf:blk.13.attn_k.weight,      torch.float16 --> F16, shape = {2048, 256}
# INFO:hf-to-gguf:blk.13.attn_v.weight,      torch.float16 --> F16, shape = {2048, 256}
# INFO:hf-to-gguf:blk.13.attn_output.weight, torch.float16 --> F16, shape = {2048, 2048}
# INFO:hf-to-gguf:blk.13.ffn_gate.weight,    torch.float16 --> F16, shape = {2048, 16384}
# INFO:hf-to-gguf:blk.13.ffn_up.weight,      torch.float16 --> F16, shape = {2048, 16384}
# INFO:hf-to-gguf:blk.13.ffn_down.weight,    torch.float16 --> F16, shape = {16384, 2048}
# INFO:hf-to-gguf:blk.13.attn_norm.weight,   torch.float16 --> F32, shape = {2048}
# INFO:hf-to-gguf:blk.13.ffn_norm.weight,    torch.float16 --> F32, shape = {2048}
# INFO:hf-to-gguf:blk.14.attn_q.weight,      torch.float16 --> F16, shape = {2048, 2048}
# INFO:hf-to-gguf:blk.14.attn_k.weight,      torch.float16 --> F16, shape = {2048, 256}
# INFO:hf-to-gguf:blk.14.attn_v.weight,      torch.float16 --> F16, shape = {2048, 256}
# INFO:hf-to-gguf:blk.14.attn_output.weight, torch.float16 --> F16, shape = {2048, 2048}
# INFO:hf-to-gguf:blk.14.ffn_gate.weight,    torch.float16 --> F16, shape = {2048, 16384}
# INFO:hf-to-gguf:blk.14.ffn_up.weight,      torch.float16 --> F16, shape = {2048, 16384}
# INFO:hf-to-gguf:blk.14.ffn_down.weight,    torch.float16 --> F16, shape = {16384, 2048}
# INFO:hf-to-gguf:blk.14.attn_norm.weight,   torch.float16 --> F32, shape = {2048}
# INFO:hf-to-gguf:blk.14.ffn_norm.weight,    torch.float16 --> F32, shape = {2048}
# INFO:hf-to-gguf:blk.15.attn_q.weight,      torch.float16 --> F16, shape = {2048, 2048}
# INFO:hf-to-gguf:blk.15.attn_k.weight,      torch.float16 --> F16, shape = {2048, 256}
# INFO:hf-to-gguf:blk.15.attn_v.weight,      torch.float16 --> F16, shape = {2048, 256}
# INFO:hf-to-gguf:blk.15.attn_output.weight, torch.float16 --> F16, shape = {2048, 2048}
# INFO:hf-to-gguf:blk.15.ffn_gate.weight,    torch.float16 --> F16, shape = {2048, 16384}
# INFO:hf-to-gguf:blk.15.ffn_up.weight,      torch.float16 --> F16, shape = {2048, 16384}
# INFO:hf-to-gguf:blk.15.ffn_down.weight,    torch.float16 --> F16, shape = {16384, 2048}
# INFO:hf-to-gguf:blk.15.attn_norm.weight,   torch.float16 --> F32, shape = {2048}
# INFO:hf-to-gguf:blk.15.ffn_norm.weight,    torch.float16 --> F32, shape = {2048}
# INFO:hf-to-gguf:blk.16.attn_q.weight,      torch.float16 --> F16, shape = {2048, 2048}
# INFO:hf-to-gguf:blk.16.attn_k.weight,      torch.float16 --> F16, shape = {2048, 256}
# INFO:hf-to-gguf:blk.16.attn_v.weight,      torch.float16 --> F16, shape = {2048, 256}
# INFO:hf-to-gguf:blk.16.attn_output.weight, torch.float16 --> F16, shape = {2048, 2048}
# INFO:hf-to-gguf:blk.16.ffn_gate.weight,    torch.float16 --> F16, shape = {2048, 16384}
# INFO:hf-to-gguf:blk.16.ffn_up.weight,      torch.float16 --> F16, shape = {2048, 16384}
# INFO:hf-to-gguf:blk.16.ffn_down.weight,    torch.float16 --> F16, shape = {16384, 2048}
# INFO:hf-to-gguf:blk.16.attn_norm.weight,   torch.float16 --> F32, shape = {2048}
# INFO:hf-to-gguf:blk.16.ffn_norm.weight,    torch.float16 --> F32, shape = {2048}
# INFO:hf-to-gguf:blk.17.attn_q.weight,      torch.float16 --> F16, shape = {2048, 2048}
# INFO:hf-to-gguf:blk.17.attn_k.weight,      torch.float16 --> F16, shape = {2048, 256}
# INFO:hf-to-gguf:blk.17.attn_v.weight,      torch.float16 --> F16, shape = {2048, 256}
# INFO:hf-to-gguf:blk.17.attn_output.weight, torch.float16 --> F16, shape = {2048, 2048}
# INFO:hf-to-gguf:blk.17.ffn_gate.weight,    torch.float16 --> F16, shape = {2048, 16384}
# INFO:hf-to-gguf:blk.17.ffn_up.weight,      torch.float16 --> F16, shape = {2048, 16384}
# INFO:hf-to-gguf:gguf: loading model part 'pytorch_model-00002-of-00002.bin'
# INFO:hf-to-gguf:blk.17.ffn_down.weight,    torch.float16 --> F16, shape = {16384, 2048}
# INFO:hf-to-gguf:blk.17.attn_norm.weight,   torch.float16 --> F32, shape = {2048}
# INFO:hf-to-gguf:blk.17.ffn_norm.weight,    torch.float16 --> F32, shape = {2048}
# INFO:hf-to-gguf:output_norm.weight,        torch.float16 --> F32, shape = {2048}
# Writing: 100%|██████████| 5.01G/5.01G [01:35<00:00, 52.4Mbyte/s]
# INFO:hf-to-gguf:Model successfully exported to 'model-unsloth.F16.gguf'
# Unsloth: Conversion completed! Output location: ./model-unsloth.F16.gguf
# Unsloth: [2] Converting GGUF 16bit into q4_k_m. This will take 20 minutes...
# main: build = 3041 (eb57fee5)
# main: built with cc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0 for x86_64-linux-gnu
# main: quantizing './model-unsloth.F16.gguf' to './model-unsloth.Q4_K_M.gguf' as Q4_K_M using 4 threads
# llama_model_loader: loaded meta data with 28 key-value pairs and 164 tensors from ./model-unsloth.F16.gguf (version GGUF V3 (latest))
# llama_model_loader: Dumping metadata keys/values. Note: KV overrides do not apply in this output.
# llama_model_loader: - kv   0:                       general.architecture str              = gemma
# llama_model_loader: - kv   1:                               general.name str              = model
# llama_model_loader: - kv   2:                       gemma.context_length u32              = 8192
# llama_model_loader: - kv   3:                     gemma.embedding_length u32              = 2048
# llama_model_loader: - kv   4:                          gemma.block_count u32              = 18
# llama_model_loader: - kv   5:                  gemma.feed_forward_length u32              = 16384
# llama_model_loader: - kv   6:                 gemma.attention.head_count u32              = 8
# llama_model_loader: - kv   7:              gemma.attention.head_count_kv u32              = 1
# llama_model_loader: - kv   8:     gemma.attention.layer_norm_rms_epsilon f32              = 0.000001
# llama_model_loader: - kv   9:                 gemma.attention.key_length u32              = 256
# llama_model_loader: - kv  10:               gemma.attention.value_length u32              = 256
# llama_model_loader: - kv  11:                          general.file_type u32              = 1
# llama_model_loader: - kv  12:                       tokenizer.ggml.model str              = llama
# llama_model_loader: - kv  13:                         tokenizer.ggml.pre str              = default
# llama_model_loader: - kv  14:                      tokenizer.ggml.tokens arr[str,256000]  = ["<pad>", "<eos>", "<bos>", "<unk>", ...
# llama_model_loader: - kv  15:                      tokenizer.ggml.scores arr[f32,256000]  = [0.000000, 0.000000, 0.000000, 0.0000...
# llama_model_loader: - kv  16:                  tokenizer.ggml.token_type arr[i32,256000]  = [3, 3, 3, 2, 1, 1, 1, 1, 1, 1, 1, 1, ...
# llama_model_loader: - kv  17:                tokenizer.ggml.bos_token_id u32              = 2
# llama_model_loader: - kv  18:                tokenizer.ggml.eos_token_id u32              = 1
# llama_model_loader: - kv  19:            tokenizer.ggml.unknown_token_id u32              = 3
# llama_model_loader: - kv  20:            tokenizer.ggml.padding_token_id u32              = 1
# llama_model_loader: - kv  21:               tokenizer.ggml.add_bos_token bool             = true
# llama_model_loader: - kv  22:               tokenizer.ggml.add_eos_token bool             = false
# llama_model_loader: - kv  23:             tokenizer.ggml.prefix_token_id u32              = 67
# llama_model_loader: - kv  24:             tokenizer.ggml.suffix_token_id u32              = 69
# llama_model_loader: - kv  25:             tokenizer.ggml.middle_token_id u32              = 68
# llama_model_loader: - kv  26:                tokenizer.ggml.eot_token_id u32              = 107
# llama_model_loader: - kv  27:               general.quantization_version u32              = 2
# llama_model_loader: - type  f32:   37 tensors
# llama_model_loader: - type  f16:  127 tensors
# [   1/ 164]                    token_embd.weight - [ 2048, 256000,     1,     1], type =    f16, converting to q6_K .. size =  1000.00 MiB ->   410.16 MiB
# [   2/ 164]                  blk.0.attn_q.weight - [ 2048,  2048,     1,     1], type =    f16, converting to q4_K .. size =     8.00 MiB ->     2.25 MiB
# [   3/ 164]                  blk.0.attn_k.weight - [ 2048,   256,     1,     1], type =    f16, converting to q4_K .. size =     1.00 MiB ->     0.28 MiB
# [   4/ 164]                  blk.0.attn_v.weight - [ 2048,   256,     1,     1], type =    f16, converting to q6_K .. size =     1.00 MiB ->     0.41 MiB
# [   5/ 164]             blk.0.attn_output.weight - [ 2048,  2048,     1,     1], type =    f16, converting to q4_K .. size =     8.00 MiB ->     2.25 MiB
# [   6/ 164]                blk.0.ffn_gate.weight - [ 2048, 16384,     1,     1], type =    f16, converting to q4_K .. size =    64.00 MiB ->    18.00 MiB
# [   7/ 164]                  blk.0.ffn_up.weight - [ 2048, 16384,     1,     1], type =    f16, converting to q4_K .. size =    64.00 MiB ->    18.00 MiB
# [   8/ 164]                blk.0.ffn_down.weight - [16384,  2048,     1,     1], type =    f16, converting to q6_K .. size =    64.00 MiB ->    26.25 MiB
# [   9/ 164]               blk.0.attn_norm.weight - [ 2048,     1,     1,     1], type =    f32, size =    0.008 MB
# [  10/ 164]                blk.0.ffn_norm.weight - [ 2048,     1,     1,     1], type =    f32, size =    0.008 MB
# [  11/ 164]                  blk.1.attn_q.weight - [ 2048,  2048,     1,     1], type =    f16, converting to q4_K .. size =     8.00 MiB ->     2.25 MiB
# [  12/ 164]                  blk.1.attn_k.weight - [ 2048,   256,     1,     1], type =    f16, converting to q4_K .. size =     1.00 MiB ->     0.28 MiB
# [  13/ 164]                  blk.1.attn_v.weight - [ 2048,   256,     1,     1], type =    f16, converting to q6_K .. size =     1.00 MiB ->     0.41 MiB
# [  14/ 164]             blk.1.attn_output.weight - [ 2048,  2048,     1,     1], type =    f16, converting to q4_K .. size =     8.00 MiB ->     2.25 MiB
# [  15/ 164]                blk.1.ffn_gate.weight - [ 2048, 16384,     1,     1], type =    f16, converting to q4_K .. size =    64.00 MiB ->    18.00 MiB
# [  16/ 164]                  blk.1.ffn_up.weight - [ 2048, 16384,     1,     1], type =    f16, converting to q4_K .. size =    64.00 MiB ->    18.00 MiB
# [  17/ 164]                blk.1.ffn_down.weight - [16384,  2048,     1,     1], type =    f16, converting to q6_K .. size =    64.00 MiB ->    26.25 MiB
# [  18/ 164]               blk.1.attn_norm.weight - [ 2048,     1,     1,     1], type =    f32, size =    0.008 MB
# [  19/ 164]                blk.1.ffn_norm.weight - [ 2048,     1,     1,     1], type =    f32, size =    0.008 MB
# [  20/ 164]                  blk.2.attn_q.weight - [ 2048,  2048,     1,     1], type =    f16, converting to q4_K .. size =     8.00 MiB ->     2.25 MiB
# [  21/ 164]                  blk.2.attn_k.weight - [ 2048,   256,     1,     1], type =    f16, converting to q4_K .. size =     1.00 MiB ->     0.28 MiB
# [  22/ 164]                  blk.2.attn_v.weight - [ 2048,   256,     1,     1], type =    f16, converting to q4_K .. size =     1.00 MiB ->     0.28 MiB
# [  23/ 164]             blk.2.attn_output.weight - [ 2048,  2048,     1,     1], type =    f16, converting to q4_K .. size =     8.00 MiB ->     2.25 MiB
# [  24/ 164]                blk.2.ffn_gate.weight - [ 2048, 16384,     1,     1], type =    f16, converting to q4_K .. size =    64.00 MiB ->    18.00 MiB
# [  25/ 164]                  blk.2.ffn_up.weight - [ 2048, 16384,     1,     1], type =    f16, converting to q4_K .. size =    64.00 MiB ->    18.00 MiB
# [  26/ 164]                blk.2.ffn_down.weight - [16384,  2048,     1,     1], type =    f16, converting to q4_K .. size =    64.00 MiB ->    18.00 MiB
# [  27/ 164]               blk.2.attn_norm.weight - [ 2048,     1,     1,     1], type =    f32, size =    0.008 MB
# [  28/ 164]                blk.2.ffn_norm.weight - [ 2048,     1,     1,     1], type =    f32, size =    0.008 MB
# [  29/ 164]                  blk.3.attn_q.weight - [ 2048,  2048,     1,     1], type =    f16, converting to q4_K .. size =     8.00 MiB ->     2.25 MiB
# [  30/ 164]                  blk.3.attn_k.weight - [ 2048,   256,     1,     1], type =    f16, converting to q4_K .. size =     1.00 MiB ->     0.28 MiB
# [  31/ 164]                  blk.3.attn_v.weight - [ 2048,   256,     1,     1], type =    f16, converting to q4_K .. size =     1.00 MiB ->     0.28 MiB
# [  32/ 164]             blk.3.attn_output.weight - [ 2048,  2048,     1,     1], type =    f16, converting to q4_K .. size =     8.00 MiB ->     2.25 MiB
# [  33/ 164]                blk.3.ffn_gate.weight - [ 2048, 16384,     1,     1], type =    f16, converting to q4_K .. size =    64.00 MiB ->    18.00 MiB
# [  34/ 164]                  blk.3.ffn_up.weight - [ 2048, 16384,     1,     1], type =    f16, converting to q4_K .. size =    64.00 MiB ->    18.00 MiB
# [  35/ 164]                blk.3.ffn_down.weight - [16384,  2048,     1,     1], type =    f16, converting to q4_K .. size =    64.00 MiB ->    18.00 MiB
# [  36/ 164]               blk.3.attn_norm.weight - [ 2048,     1,     1,     1], type =    f32, size =    0.008 MB
# [  37/ 164]                blk.3.ffn_norm.weight - [ 2048,     1,     1,     1], type =    f32, size =    0.008 MB
# [  38/ 164]                  blk.4.attn_q.weight - [ 2048,  2048,     1,     1], type =    f16, converting to q4_K .. size =     8.00 MiB ->     2.25 MiB
# [  39/ 164]                  blk.4.attn_k.weight - [ 2048,   256,     1,     1], type =    f16, converting to q4_K .. size =     1.00 MiB ->     0.28 MiB
# [  40/ 164]                  blk.4.attn_v.weight - [ 2048,   256,     1,     1], type =    f16, converting to q6_K .. size =     1.00 MiB ->     0.41 MiB
# [  41/ 164]             blk.4.attn_output.weight - [ 2048,  2048,     1,     1], type =    f16, converting to q4_K .. size =     8.00 MiB ->     2.25 MiB
# [  42/ 164]                blk.4.ffn_gate.weight - [ 2048, 16384,     1,     1], type =    f16, converting to q4_K .. size =    64.00 MiB ->    18.00 MiB
# [  43/ 164]                  blk.4.ffn_up.weight - [ 2048, 16384,     1,     1], type =    f16, converting to q4_K .. size =    64.00 MiB ->    18.00 MiB
# [  44/ 164]                blk.4.ffn_down.weight - [16384,  2048,     1,     1], type =    f16, converting to q6_K .. size =    64.00 MiB ->    26.25 MiB
# [  45/ 164]               blk.4.attn_norm.weight - [ 2048,     1,     1,     1], type =    f32, size =    0.008 MB
# [  46/ 164]                blk.4.ffn_norm.weight - [ 2048,     1,     1,     1], type =    f32, size =    0.008 MB
# [  47/ 164]                  blk.5.attn_q.weight - [ 2048,  2048,     1,     1], type =    f16, converting to q4_K .. size =     8.00 MiB ->     2.25 MiB
# [  48/ 164]                  blk.5.attn_k.weight - [ 2048,   256,     1,     1], type =    f16, converting to q4_K .. size =     1.00 MiB ->     0.28 MiB
# [  49/ 164]                  blk.5.attn_v.weight - [ 2048,   256,     1,     1], type =    f16, converting to q4_K .. size =     1.00 MiB ->     0.28 MiB
# [  50/ 164]             blk.5.attn_output.weight - [ 2048,  2048,     1,     1], type =    f16, converting to q4_K .. size =     8.00 MiB ->     2.25 MiB
# [  51/ 164]                blk.5.ffn_gate.weight - [ 2048, 16384,     1,     1], type =    f16, converting to q4_K .. size =    64.00 MiB ->    18.00 MiB
# [  52/ 164]                  blk.5.ffn_up.weight - [ 2048, 16384,     1,     1], type =    f16, converting to q4_K .. size =    64.00 MiB ->    18.00 MiB
# [  53/ 164]                blk.5.ffn_down.weight - [16384,  2048,     1,     1], type =    f16, converting to q4_K .. size =    64.00 MiB ->    18.00 MiB
# [  54/ 164]               blk.5.attn_norm.weight - [ 2048,     1,     1,     1], type =    f32, size =    0.008 MB
# [  55/ 164]                blk.5.ffn_norm.weight - [ 2048,     1,     1,     1], type =    f32, size =    0.008 MB
# [  56/ 164]                  blk.6.attn_q.weight - [ 2048,  2048,     1,     1], type =    f16, converting to q4_K .. size =     8.00 MiB ->     2.25 MiB
# [  57/ 164]                  blk.6.attn_k.weight - [ 2048,   256,     1,     1], type =    f16, converting to q4_K .. size =     1.00 MiB ->     0.28 MiB
# [  58/ 164]                  blk.6.attn_v.weight - [ 2048,   256,     1,     1], type =    f16, converting to q4_K .. size =     1.00 MiB ->     0.28 MiB
# [  59/ 164]             blk.6.attn_output.weight - [ 2048,  2048,     1,     1], type =    f16, converting to q4_K .. size =     8.00 MiB ->     2.25 MiB
# [  60/ 164]                blk.6.ffn_gate.weight - [ 2048, 16384,     1,     1], type =    f16, converting to q4_K .. size =    64.00 MiB ->    18.00 MiB
# [  61/ 164]                  blk.6.ffn_up.weight - [ 2048, 16384,     1,     1], type =    f16, converting to q4_K .. size =    64.00 MiB ->    18.00 MiB
# [  62/ 164]                blk.6.ffn_down.weight - [16384,  2048,     1,     1], type =    f16, converting to q4_K .. size =    64.00 MiB ->    18.00 MiB
# [  63/ 164]               blk.6.attn_norm.weight - [ 2048,     1,     1,     1], type =    f32, size =    0.008 MB
# [  64/ 164]                blk.6.ffn_norm.weight - [ 2048,     1,     1,     1], type =    f32, size =    0.008 MB
# [  65/ 164]                  blk.7.attn_q.weight - [ 2048,  2048,     1,     1], type =    f16, converting to q4_K .. size =     8.00 MiB ->     2.25 MiB
# [  66/ 164]                  blk.7.attn_k.weight - [ 2048,   256,     1,     1], type =    f16, converting to q4_K .. size =     1.00 MiB ->     0.28 MiB
# [  67/ 164]                  blk.7.attn_v.weight - [ 2048,   256,     1,     1], type =    f16, converting to q6_K .. size =     1.00 MiB ->     0.41 MiB
# [  68/ 164]             blk.7.attn_output.weight - [ 2048,  2048,     1,     1], type =    f16, converting to q4_K .. size =     8.00 MiB ->     2.25 MiB
# [  69/ 164]                blk.7.ffn_gate.weight - [ 2048, 16384,     1,     1], type =    f16, converting to q4_K .. size =    64.00 MiB ->    18.00 MiB
# [  70/ 164]                  blk.7.ffn_up.weight - [ 2048, 16384,     1,     1], type =    f16, converting to q4_K .. size =    64.00 MiB ->    18.00 MiB
# [  71/ 164]                blk.7.ffn_down.weight - [16384,  2048,     1,     1], type =    f16, converting to q6_K .. size =    64.00 MiB ->    26.25 MiB
# [  72/ 164]               blk.7.attn_norm.weight - [ 2048,     1,     1,     1], type =    f32, size =    0.008 MB
# [  73/ 164]                blk.7.ffn_norm.weight - [ 2048,     1,     1,     1], type =    f32, size =    0.008 MB
# [  74/ 164]                  blk.8.attn_q.weight - [ 2048,  2048,     1,     1], type =    f16, converting to q4_K .. size =     8.00 MiB ->     2.25 MiB
# [  75/ 164]                  blk.8.attn_k.weight - [ 2048,   256,     1,     1], type =    f16, converting to q4_K .. size =     1.00 MiB ->     0.28 MiB
# [  76/ 164]                  blk.8.attn_v.weight - [ 2048,   256,     1,     1], type =    f16, converting to q4_K .. size =     1.00 MiB ->     0.28 MiB
# [  77/ 164]             blk.8.attn_output.weight - [ 2048,  2048,     1,     1], type =    f16, converting to q4_K .. size =     8.00 MiB ->     2.25 MiB
# [  78/ 164]                blk.8.ffn_gate.weight - [ 2048, 16384,     1,     1], type =    f16, converting to q4_K .. size =    64.00 MiB ->    18.00 MiB
# [  79/ 164]                  blk.8.ffn_up.weight - [ 2048, 16384,     1,     1], type =    f16, converting to q4_K .. size =    64.00 MiB ->    18.00 MiB
# [  80/ 164]                blk.8.ffn_down.weight - [16384,  2048,     1,     1], type =    f16, converting to q4_K .. size =    64.00 MiB ->    18.00 MiB
# [  81/ 164]               blk.8.attn_norm.weight - [ 2048,     1,     1,     1], type =    f32, size =    0.008 MB
# [  82/ 164]                blk.8.ffn_norm.weight - [ 2048,     1,     1,     1], type =    f32, size =    0.008 MB
# [  83/ 164]                  blk.9.attn_q.weight - [ 2048,  2048,     1,     1], type =    f16, converting to q4_K .. size =     8.00 MiB ->     2.25 MiB
# [  84/ 164]                  blk.9.attn_k.weight - [ 2048,   256,     1,     1], type =    f16, converting to q4_K .. size =     1.00 MiB ->     0.28 MiB
# [  85/ 164]                  blk.9.attn_v.weight - [ 2048,   256,     1,     1], type =    f16, converting to q4_K .. size =     1.00 MiB ->     0.28 MiB
# [  86/ 164]             blk.9.attn_output.weight - [ 2048,  2048,     1,     1], type =    f16, converting to q4_K .. size =     8.00 MiB ->     2.25 MiB
# [  87/ 164]                blk.9.ffn_gate.weight - [ 2048, 16384,     1,     1], type =    f16, converting to q4_K .. size =    64.00 MiB ->    18.00 MiB
# [  88/ 164]                  blk.9.ffn_up.weight - [ 2048, 16384,     1,     1], type =    f16, converting to q4_K .. size =    64.00 MiB ->    18.00 MiB
# [  89/ 164]                blk.9.ffn_down.weight - [16384,  2048,     1,     1], type =    f16, converting to q4_K .. size =    64.00 MiB ->    18.00 MiB
# [  90/ 164]               blk.9.attn_norm.weight - [ 2048,     1,     1,     1], type =    f32, size =    0.008 MB
# [  91/ 164]                blk.9.ffn_norm.weight - [ 2048,     1,     1,     1], type =    f32, size =    0.008 MB
# [  92/ 164]                 blk.10.attn_q.weight - [ 2048,  2048,     1,     1], type =    f16, converting to q4_K .. size =     8.00 MiB ->     2.25 MiB
# [  93/ 164]                 blk.10.attn_k.weight - [ 2048,   256,     1,     1], type =    f16, converting to q4_K .. size =     1.00 MiB ->     0.28 MiB
# [  94/ 164]                 blk.10.attn_v.weight - [ 2048,   256,     1,     1], type =    f16, converting to q6_K .. size =     1.00 MiB ->     0.41 MiB
# [  95/ 164]            blk.10.attn_output.weight - [ 2048,  2048,     1,     1], type =    f16, converting to q4_K .. size =     8.00 MiB ->     2.25 MiB
# [  96/ 164]               blk.10.ffn_gate.weight - [ 2048, 16384,     1,     1], type =    f16, converting to q4_K .. size =    64.00 MiB ->    18.00 MiB
# [  97/ 164]                 blk.10.ffn_up.weight - [ 2048, 16384,     1,     1], type =    f16, converting to q4_K .. size =    64.00 MiB ->    18.00 MiB
# [  98/ 164]               blk.10.ffn_down.weight - [16384,  2048,     1,     1], type =    f16, converting to q6_K .. size =    64.00 MiB ->    26.25 MiB
# [  99/ 164]              blk.10.attn_norm.weight - [ 2048,     1,     1,     1], type =    f32, size =    0.008 MB
# [ 100/ 164]               blk.10.ffn_norm.weight - [ 2048,     1,     1,     1], type =    f32, size =    0.008 MB
# [ 101/ 164]                 blk.11.attn_q.weight - [ 2048,  2048,     1,     1], type =    f16, converting to q4_K .. size =     8.00 MiB ->     2.25 MiB
# [ 102/ 164]                 blk.11.attn_k.weight - [ 2048,   256,     1,     1], type =    f16, converting to q4_K .. size =     1.00 MiB ->     0.28 MiB
# [ 103/ 164]                 blk.11.attn_v.weight - [ 2048,   256,     1,     1], type =    f16, converting to q4_K .. size =     1.00 MiB ->     0.28 MiB
# [ 104/ 164]            blk.11.attn_output.weight - [ 2048,  2048,     1,     1], type =    f16, converting to q4_K .. size =     8.00 MiB ->     2.25 MiB
# [ 105/ 164]               blk.11.ffn_gate.weight - [ 2048, 16384,     1,     1], type =    f16, converting to q4_K .. size =    64.00 MiB ->    18.00 MiB
# [ 106/ 164]                 blk.11.ffn_up.weight - [ 2048, 16384,     1,     1], type =    f16, converting to q4_K .. size =    64.00 MiB ->    18.00 MiB
# [ 107/ 164]               blk.11.ffn_down.weight - [16384,  2048,     1,     1], type =    f16, converting to q4_K .. size =    64.00 MiB ->    18.00 MiB
# [ 108/ 164]              blk.11.attn_norm.weight - [ 2048,     1,     1,     1], type =    f32, size =    0.008 MB
# [ 109/ 164]               blk.11.ffn_norm.weight - [ 2048,     1,     1,     1], type =    f32, size =    0.008 MB
# [ 110/ 164]                 blk.12.attn_q.weight - [ 2048,  2048,     1,     1], type =    f16, converting to q4_K .. size =     8.00 MiB ->     2.25 MiB
# [ 111/ 164]                 blk.12.attn_k.weight - [ 2048,   256,     1,     1], type =    f16, converting to q4_K .. size =     1.00 MiB ->     0.28 MiB
# [ 112/ 164]                 blk.12.attn_v.weight - [ 2048,   256,     1,     1], type =    f16, converting to q4_K .. size =     1.00 MiB ->     0.28 MiB
# [ 113/ 164]            blk.12.attn_output.weight - [ 2048,  2048,     1,     1], type =    f16, converting to q4_K .. size =     8.00 MiB ->     2.25 MiB
# [ 114/ 164]               blk.12.ffn_gate.weight - [ 2048, 16384,     1,     1], type =    f16, converting to q4_K .. size =    64.00 MiB ->    18.00 MiB
# [ 115/ 164]                 blk.12.ffn_up.weight - [ 2048, 16384,     1,     1], type =    f16, converting to q4_K .. size =    64.00 MiB ->    18.00 MiB
# [ 116/ 164]               blk.12.ffn_down.weight - [16384,  2048,     1,     1], type =    f16, converting to q4_K .. size =    64.00 MiB ->    18.00 MiB
# [ 117/ 164]              blk.12.attn_norm.weight - [ 2048,     1,     1,     1], type =    f32, size =    0.008 MB
# [ 118/ 164]               blk.12.ffn_norm.weight - [ 2048,     1,     1,     1], type =    f32, size =    0.008 MB
# [ 119/ 164]                 blk.13.attn_q.weight - [ 2048,  2048,     1,     1], type =    f16, converting to q4_K .. size =     8.00 MiB ->     2.25 MiB
# [ 120/ 164]                 blk.13.attn_k.weight - [ 2048,   256,     1,     1], type =    f16, converting to q4_K .. size =     1.00 MiB ->     0.28 MiB
# [ 121/ 164]                 blk.13.attn_v.weight - [ 2048,   256,     1,     1], type =    f16, converting to q6_K .. size =     1.00 MiB ->     0.41 MiB
# [ 122/ 164]            blk.13.attn_output.weight - [ 2048,  2048,     1,     1], type =    f16, converting to q4_K .. size =     8.00 MiB ->     2.25 MiB
# [ 123/ 164]               blk.13.ffn_gate.weight - [ 2048, 16384,     1,     1], type =    f16, converting to q4_K .. size =    64.00 MiB ->    18.00 MiB
# [ 124/ 164]                 blk.13.ffn_up.weight - [ 2048, 16384,     1,     1], type =    f16, converting to q4_K .. size =    64.00 MiB ->    18.00 MiB
# [ 125/ 164]               blk.13.ffn_down.weight - [16384,  2048,     1,     1], type =    f16, converting to q6_K .. size =    64.00 MiB ->    26.25 MiB
# [ 126/ 164]              blk.13.attn_norm.weight - [ 2048,     1,     1,     1], type =    f32, size =    0.008 MB
# [ 127/ 164]               blk.13.ffn_norm.weight - [ 2048,     1,     1,     1], type =    f32, size =    0.008 MB
# [ 128/ 164]                 blk.14.attn_q.weight - [ 2048,  2048,     1,     1], type =    f16, converting to q4_K .. size =     8.00 MiB ->     2.25 MiB
# [ 129/ 164]                 blk.14.attn_k.weight - [ 2048,   256,     1,     1], type =    f16, converting to q4_K .. size =     1.00 MiB ->     0.28 MiB
# [ 130/ 164]                 blk.14.attn_v.weight - [ 2048,   256,     1,     1], type =    f16, converting to q4_K .. size =     1.00 MiB ->     0.28 MiB
# [ 131/ 164]            blk.14.attn_output.weight - [ 2048,  2048,     1,     1], type =    f16, converting to q4_K .. size =     8.00 MiB ->     2.25 MiB
# [ 132/ 164]               blk.14.ffn_gate.weight - [ 2048, 16384,     1,     1], type =    f16, converting to q4_K .. size =    64.00 MiB ->    18.00 MiB
# [ 133/ 164]                 blk.14.ffn_up.weight - [ 2048, 16384,     1,     1], type =    f16, converting to q4_K .. size =    64.00 MiB ->    18.00 MiB
# [ 134/ 164]               blk.14.ffn_down.weight - [16384,  2048,     1,     1], type =    f16, converting to q4_K .. size =    64.00 MiB ->    18.00 MiB
# [ 135/ 164]              blk.14.attn_norm.weight - [ 2048,     1,     1,     1], type =    f32, size =    0.008 MB
# [ 136/ 164]               blk.14.ffn_norm.weight - [ 2048,     1,     1,     1], type =    f32, size =    0.008 MB
# [ 137/ 164]                 blk.15.attn_q.weight - [ 2048,  2048,     1,     1], type =    f16, converting to q4_K .. size =     8.00 MiB ->     2.25 MiB
# [ 138/ 164]                 blk.15.attn_k.weight - [ 2048,   256,     1,     1], type =    f16, converting to q4_K .. size =     1.00 MiB ->     0.28 MiB
# [ 139/ 164]                 blk.15.attn_v.weight - [ 2048,   256,     1,     1], type =    f16, converting to q6_K .. size =     1.00 MiB ->     0.41 MiB
# [ 140/ 164]            blk.15.attn_output.weight - [ 2048,  2048,     1,     1], type =    f16, converting to q4_K .. size =     8.00 MiB ->     2.25 MiB
# [ 141/ 164]               blk.15.ffn_gate.weight - [ 2048, 16384,     1,     1], type =    f16, converting to q4_K .. size =    64.00 MiB ->    18.00 MiB
# [ 142/ 164]                 blk.15.ffn_up.weight - [ 2048, 16384,     1,     1], type =    f16, converting to q4_K .. size =    64.00 MiB ->    18.00 MiB
# [ 143/ 164]               blk.15.ffn_down.weight - [16384,  2048,     1,     1], type =    f16, converting to q6_K .. size =    64.00 MiB ->    26.25 MiB
# [ 144/ 164]              blk.15.attn_norm.weight - [ 2048,     1,     1,     1], type =    f32, size =    0.008 MB
# [ 145/ 164]               blk.15.ffn_norm.weight - [ 2048,     1,     1,     1], type =    f32, size =    0.008 MB
# [ 146/ 164]                 blk.16.attn_q.weight - [ 2048,  2048,     1,     1], type =    f16, converting to q4_K .. size =     8.00 MiB ->     2.25 MiB
# [ 147/ 164]                 blk.16.attn_k.weight - [ 2048,   256,     1,     1], type =    f16, converting to q4_K .. size =     1.00 MiB ->     0.28 MiB
# [ 148/ 164]                 blk.16.attn_v.weight - [ 2048,   256,     1,     1], type =    f16, converting to q6_K .. size =     1.00 MiB ->     0.41 MiB
# [ 149/ 164]            blk.16.attn_output.weight - [ 2048,  2048,     1,     1], type =    f16, converting to q4_K .. size =     8.00 MiB ->     2.25 MiB
# [ 150/ 164]               blk.16.ffn_gate.weight - [ 2048, 16384,     1,     1], type =    f16, converting to q4_K .. size =    64.00 MiB ->    18.00 MiB
# [ 151/ 164]                 blk.16.ffn_up.weight - [ 2048, 16384,     1,     1], type =    f16, converting to q4_K .. size =    64.00 MiB ->    18.00 MiB
# [ 152/ 164]               blk.16.ffn_down.weight - [16384,  2048,     1,     1], type =    f16, converting to q6_K .. size =    64.00 MiB ->    26.25 MiB
# [ 153/ 164]              blk.16.attn_norm.weight - [ 2048,     1,     1,     1], type =    f32, size =    0.008 MB
# [ 154/ 164]               blk.16.ffn_norm.weight - [ 2048,     1,     1,     1], type =    f32, size =    0.008 MB
# [ 155/ 164]                 blk.17.attn_q.weight - [ 2048,  2048,     1,     1], type =    f16, converting to q4_K .. size =     8.00 MiB ->     2.25 MiB
# [ 156/ 164]                 blk.17.attn_k.weight - [ 2048,   256,     1,     1], type =    f16, converting to q4_K .. size =     1.00 MiB ->     0.28 MiB
# [ 157/ 164]                 blk.17.attn_v.weight - [ 2048,   256,     1,     1], type =    f16, converting to q6_K .. size =     1.00 MiB ->     0.41 MiB
# [ 158/ 164]            blk.17.attn_output.weight - [ 2048,  2048,     1,     1], type =    f16, converting to q4_K .. size =     8.00 MiB ->     2.25 MiB
# [ 159/ 164]               blk.17.ffn_gate.weight - [ 2048, 16384,     1,     1], type =    f16, converting to q4_K .. size =    64.00 MiB ->    18.00 MiB
# [ 160/ 164]                 blk.17.ffn_up.weight - [ 2048, 16384,     1,     1], type =    f16, converting to q4_K .. size =    64.00 MiB ->    18.00 MiB
# [ 161/ 164]               blk.17.ffn_down.weight - [16384,  2048,     1,     1], type =    f16, converting to q6_K .. size =    64.00 MiB ->    26.25 MiB
# [ 162/ 164]              blk.17.attn_norm.weight - [ 2048,     1,     1,     1], type =    f32, size =    0.008 MB
# [ 163/ 164]               blk.17.ffn_norm.weight - [ 2048,     1,     1,     1], type =    f32, size =    0.008 MB
# [ 164/ 164]                   output_norm.weight - [ 2048,     1,     1,     1], type =    f32, size =    0.008 MB
# llama_model_quantize_internal: model size  =  4780.29 MB
# llama_model_quantize_internal: quant size  =  1548.98 MB
#
# main: quantize time = 313205.72 ms
# main:    total time = 313205.72 ms
# Unsloth: Conversion completed! Output location: ./model-unsloth.Q4_K_M.gguf

# %%
# copy the quantized model to google drive
# !cp -r /content/model-unsloth.Q4_K_M.gguf /content/drive/MyDrive/models/emotion_analysis_gemma_2b__v3.4.0.gguf

# %%
# copy the model safetensors to google drive
# !cp -r /content/emotion_analysis_gemma_2b__v3.4.0__safetensors.tar.gz /content/drive/MyDrive/models/
